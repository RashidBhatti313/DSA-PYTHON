# %%
class Node:
    def __init__(self, data) -> None:
        self.next = None
        self.data = data

class Slist:
    def __init__(self) -> None:
        self.count = 0
        self.head = None 
        self.tail = None
    
    def is_empty(self):
        return (self.head is None) or (self.count == 0)

    def insertAtFirst(self, data):
        new_node = Node(data)
        if self.is_empty():
            self.head = new_node
            self.tail = new_node
            
        else:
            new_node.next = self.head
            self.head = new_node
        self.count += 1
    
    def insertAtLast(self,data):
        new_node = Node(data)
        if self.is_empty():
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            self.tail = new_node

        self.count += 1

    def search(self,e):
        if not self.is_empty():
            x = self.head

            while x:
                if x.data == e:
                    return x
                x = x.next
            return None
            
    def show(self):
        if not self.is_empty():
            x = self.head
            while x:
                print(x.data)
                x = x.next
        else:
            return None
        
    def insertAfter(self, per_node, data):
        if self.is_empty():
            return None
        else:
            new_node = Node(data)
            new_node.next = per_node.next
            per_node.next = new_node
        self.count +=1

    def insertAfterValue(self, value, data):
        if self.is_empty():
            return None
        else:
            new_node = Node(data)
            per_node = self.search(value)
            new_node.next = per_node.next
            per_node.next = new_node
        self.count +=1
         
    def delete_at_begining(self):
        if self.is_empty():
            return None
        elif self.count == 1:
            self.head = None
            self.tail = None
            self.count  -= 1
            
        else:
            s = self.head
            self.head = self.head.next
            s = None
            self.count  -= 1
    
    def delete_at_end(self):
        if self.is_empty():
            return None
        elif self.count ==1:
            self.head = None
            self.tail = None
            self.count  -= 1
        else:
            x = self.head
            while x.next != self.tail:
                x = x.next
            self.tail = x
            self.tail.next = None
            self.count -=1
    
    def delete_at_specific_value(self, e):
        x = self.head
        while x:
            if x.next.data == e:
                x.next = x.next.next
                self.count -=1
                return 

            x = x.next
        return None



        




s = Slist()
s.is_empty()
s.insertAtFirst(222)

s.insertAtFirst(22332)
s.insertAtFirst(2222)
s.insertAtLast("mao she she")

# print(s.search(2222).data)
s.insertAtLast("ponka")
s.insertAtFirst(2221434)
s.tail.data
pervious_node = s.search("mao she she")
s.insertAfter(pervious_node, "khushka")
s.insertAfterValue(2222,9990999)
s.delete_at_begining()
s.delete_at_end()
s.delete_at_specific_value(22332)

s.show()
s.count
# Out:
# 2222
# 9990999
# 222
# mao she she
# khushka
# 5

# %%
class Node:
    def __init__(self, data) -> None:
        self.data = data
        self.next = None

class SingleLinkedList:
    def __init__(self) -> None:
        self.head = None
        self.tail = None
        self.count = 0

    def is_empty(self):
        return (self.head is None) or (self.count == 0)

    def insert_at_first(self, data):
        newnode = Node(data)
        if self.is_empty():
            self.head = newnode
            self.tail = newnode
        else:
            newnode.next = self.head
            self.head = newnode
        self.count += 1

    def insert_at_last(self, data):
        newnode = Node(data)
        if self.is_empty():
            self.head = newnode
            self.tail = newnode
        else:
            self.tail.next = newnode
            self.tail = newnode
        self.count += 1

    def Insert_After(self, position, data):
        if self.is_empty():
            return None
        else:
            newnode = Node(data)
            newnode.next = position.next
            position.next = newnode
        self.count += 1

    def Insert_After_value(self, value, data):
        if self.is_empty():
            return None
        else:
            newnode = Node(data)
            position = self.search(value)
            newnode.next = position.next
            position.next = newnode
        self.count += 1
        

    def search(self, e):
        if not self.is_empty():
            x = self.head
            while x:
                if x.data == e:
                    return x
                x = x.next
            return None

    def show(self):
        if not self.is_empty():
            x = self.head
            while x:
                print(x.data)
                x = x.next
        else:
            return None

SLint = SingleLinkedList()
SLint.is_empty()
SLint.insert_at_first(444)
SLint.insert_at_first(555)
SLint.insert_at_first(666)
SLint.insert_at_first(777)
SLint.insert_at_last("Last")
SLint.insert_at_last("Akhri")
SLint.insert_at_last("End")
pervious_node = SLint.search("Akhri")
SLint.Insert_After(pervious_node, "The End")
SLint.insert_at_first(888)
SLint.insert_at_first(999)
SLint.Insert_After_value(888, 898989)
print(SLint.search(444).data)
SLint.show()
# SLint.head.data
SLint.count
# Out:
# 444
# 999
# 888
# 898989
# 777
# 666
# 555
# 444
# Last
# Akhri
# The End
# End
# 11

# %%
class Node:
    def __init__(self, data) -> None:
        self.data = data
        self.next = None
class Stack:# LIFo
    def __init__(self) -> None:
        self.top = None
        self.count  = 0
    
    def is_empty(self):
        return self.top is None
    
    def push(self, e):
        newnode = Node(e)
        if self.is_empty():
            self.top = newnode
        else:
            self.top.next = newnode
            self.top = newnode
        self.count +=1

    def pop(self):
        if self.is_empty():
            x = self.top
            while x:
                

s = Stack()
s.is_empty()

s.push(33)
s.push("aljjflsd")
s.push("djfk")
s.push("Zaki")
# Out:
# 'Zaki'
