# %%
class Node:
    def __init__(self, data) -> None:
        self.data = data
        self.next = None
        self.previous = None

n1 = Node("Karachi")
n2 = Node([1, 2, 3, 4, 5])
n3 = Node({"MATHEMATICS" : 8})
n4 = Node(10)

n1.next = n2
n2.previous = n1
n2.next = n3
n3.previous = n2
n3.next = n4
n4.previous = n3

print(n1.next.previous.data)

class Double_Linked_list:
    def __init__(self) -> None:
        self.head = None
        self.tail = None
        self.count = 0

    def is_empty(self):
        return (self.head is None) or (self.count == 0)
    
    def insert_at_begining(self, data):
        newnode = Node(data)
        if self.is_empty():
            self.head = newnode
            self.tail = newnode
        else:
            newnode.next = self.head
            self.head.previous = newnode
            self.head = newnode
        self.count += 1

    def insert_at_Last(self, data):
        newnode = Node(data)
        if self.is_empty():
            self.head = newnode
            self.tail = newnode
        else:
            newnode.previous = self.tail
            self.tail.next = newnode
            self.tail = newnode
        self.count += 1

    def search(self,e):
        if not self.is_empty():
            x = self.head
            while x:
                if x.data == e:
                    return x
                x = x.next
            return None

    def insert_at_After_Value(self, data, e):
        if self.is_empty():
            return None      
        else:
            x = self.search(e)
            newnode = Node(data)
            newnode.next = x.next
            newnode.previous = x
            newnode.next.previous = newnode
            x.next = newnode            

    def delete_at_first(self):
        if self.is_empty():
            return None
        else:           
            self.head = self.head.next
            self.head.previous = None
        self.count -= 1

    def delete_at_end(self):
        if self.is_empty():
            return None
        else:
            self.tail = self.tail.previous
            self.tail.next = None
        self.count -= 1 
            
    def delete_at_after_value(self, e):
        if self.is_empty():
            return None
        elif self.count == 1:
            self.head = None
            self.tail = None
        else:
            n = self.search(e)
            n.previous.next = n.next
            n.next.previous = n.previous.previous
        self.count -= 1

    def show(self):
        if not self.is_empty():
            x = self.head
            while x:
                print(x.data)
                x = x.next
            else:
                return None
        


Dlist = Double_Linked_list()
Dlist.is_empty()
Dlist.insert_at_Last(777)
Dlist.insert_at_Last(666)
Dlist.insert_at_Last(555)
Dlist.insert_at_Last(444)
Dlist.insert_at_Last(333)
Dlist.insert_at_begining(333)
Dlist.insert_at_begining(989)
Dlist.insert_at_begining(789)
Dlist.insert_at_begining(7456)
Dlist.insert_at_begining(2135)
# Dlist.insert_at_After_Value(14444444,989)
# Dlist.delete_at_first()
# Dlist.delete_at_after_value(789)
# Dlist.delete_at_end()
Dlist.show()
Dlist.search(777)
Dlist.count
Dlist.head.data


l2 = Double_Linked_list()
l2.insert_at_begining(3)
l2.insert_at_begining(333)
l2.insert_at_begining(323)
l2.insert_at_begining(331)
l2.insert_at_begining(363)

# def merge(l1,l2):
#     l1.tail.next = l2.head
#     l2.head.previous = l1.tail

# def transversal(Dlist):
#     x = Dlist.head
#     while x:
#         print(x.data)
#         x = x.next
    
# merge(Dlist,l2)

# transversal(Dlist)

# def sorting(data):
#     if not self.head:


# x = sorting(Dlist)
# print(x)
# Out:
# Karachi
# 2135
# 7456
# 789
# 989
# 333
# 777
# 666
# 555
# 444
# 333
# 2135
# 7456
# 789
# 989
# 333
# 777
# 666
# 555
# 444
# 333
# 363
# 331
# 323
# 333
# 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 163
#     160                 data[j],data[j + 1] = data[j + 1], data[j]
#     161     return data
# --> 163 x = sorting(Dlist)
#     164 print(x)
#
# Cell In[6], line 155, in sorting(data)
#     154 def sorting(data):
# --> 155     n = len(data) -1
#     157     for i in range(n):
#     158         for j in range(n - i):
#
# TypeError: object of type 'Double_Linked_list' has no len()

# %%
class Node:
    def __init__(self, data) -> None:
        self.data = data
        self.next = None
        self.previous = None

n1 = Node("Karachi")
n2 = Node([1, 2, 3, 4, 5])
n3 = Node({"Computer Science" : 10})
n4 = Node(12)

n1.next = n2
n2.previous = n1
n2.next = n3
n3.previous = n2
n3.next = n4
n4.previous = n3

print(n1.next.next.previous.next.next.data)

class Double_Linked_list:
    def __init__(self) -> None:
        self.head = None
        self.tail = None
        self.count = 0

    def is_empty(self):
        return (self.head is None) or (self.count == 0)
    
    def insert_at_begining(self, data):
        newnode = Node(data)
        if self.is_empty():
            self.head = newnode
            self.tail = newnode
        else:
            newnode.next = self.head
            self.head.previous = newnode
            self.head = newnode
        self.count += 1

    def insert_at_Last(self, data):
        newnode = Node(data)
        if self.is_empty():
            self.head = newnode
            self.tail = newnode
        else:
            newnode.previous = self.tail
            self.tail.next = newnode
            self.tail = newnode
        self.count += 1

    def search(self, e):
        if not self.is_empty():
            x = self.head
            while x:
                if x.data == e:
                    return x
                x = x.next
            return None
        
    def insert_at_After_Value(self, data, e):
        if self.is_empty():
            return None
        else:
            x = self.search(e)
            newnode = Node(data)
            newnode.next = x.next
            newnode.previous = x
            newnode.next.previous = newnode
            x.next = newnode

    def delete_at_first(self):
        if self.is_empty():
            return None
        else:           
            self.head = self.head.next
            self.head.previous = None
        self.count -= 1

    def delete_at_end(self):
        if self.is_empty():
            return None
        else:
            self.tail = self.tail.previous
            self.tail.next = None
        self.count -= 1

    def delete_at_after_value(self, e):
        if self.is_empty():
            return None
        elif self.count == 1:
            self.head = None
            self.tail = None
        else:
            n = self.search(e)
            n.previous.next = n.next
            n.next.previous = n.previous.previous
        self.count -= 1

    def show(self):
        if not self.is_empty():
            x = self.head
            while x:
                print(x.data)
                x = x.next
            else:
                return None
            
Dlist = Double_Linked_list()
Dlist.is_empty()
Dlist.insert_at_Last(777)
Dlist.insert_at_Last(666)
Dlist.insert_at_Last(555)
Dlist.insert_at_Last(444)
Dlist.insert_at_Last(333)
Dlist.insert_at_begining(333)
Dlist.insert_at_begining(989)
Dlist.insert_at_begining(789)
Dlist.insert_at_begining(7456)
Dlist.insert_at_begining(2135)
# Dlist.insert_at_After_Value(14444444,989)
# Dlist.delete_at_first()
# Dlist.delete_at_after_value(789)
# Dlist.delete_at_end()
Dlist.show()
Dlist.search(777)
Dlist.count
Dlist.head.data

def merge(l1, l2):
    l1.tail.next = l2.head
    l2.head.previous = l1.tail

def transversal(Dlist):
    x = Dlist.head
    while x:
        print(x.data)
        x = x.next

merge(Dlist, l2)

transversal(Dlist)
# Out:
# 12
# 2135
# 7456
# 789
# 989
# 333
# 777
# 666
# 555
# 444
# 333
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 140
#     137         print(x.data)
#     138         x = x.next
# --> 140 merge(Dlist, l2)
#     142 transversal(Dlist)
#
# NameError: name 'l2' is not defined
